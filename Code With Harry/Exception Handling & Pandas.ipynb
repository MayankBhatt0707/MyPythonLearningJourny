# %%
try:
    lst = [int(x) for x in input().split()]
    i = int(input("Enter Index: "))
    print(lst[i])
        
except Exception as e:
        print("Exception Occured: ", e)
        lst = 0
finally:
            print(lst)
# Out:
# 12, 20, 30,40
# Exception Occured:  invalid literal for int() with base 10: '12,'
# 0

# %%
employee = [{"id": 1, "first_name": "Mayank", "last_name": "Bhatt"}]
try:
    for employee in employee: 
        full_name = employee['first_name'] + employee['middle_name'] + employee['last_name'] 
        print(full_name)
except KeyError as e:
    full_name = employee['first_name'] + employee['last_name'] 
    print(full_name)
# Out:
# MayankBhatt

# %%
import pandas as pd

# %%
d = pd.read_csv("C:\\Users\\m9wrc\\OneDrive\\Desktop\\Python\\movies.csv")

# %%
d.head(2,)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English

# %%
d.shape
# Out:
# (37, 10)

# %%
d.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
d.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
d.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
d.language.value_counts()
# Out:
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: language, dtype: int64

# %%
d[["title", "industry", "budget"]]
# Out:
#                                           title   industry    budget
# 0                               Pather Panchali  Bollywood  70000.00
# 1   Doctor Strange in the Multiverse of Madness  Hollywood    200.00
# 2                         Thor: The Dark World   Hollywood    165.00
# 3                               Thor: Ragnarok   Hollywood    180.00
# 4                       Thor: Love and Thunder   Hollywood    250.00
# 5                      The Shawshank Redemption  Hollywood     25.00
# 6                                  Interstellar  Hollywood    165.00
# 7                      The Pursuit of Happyness  Hollywood     55.00
# 8                                     Gladiator  Hollywood    103.00
# 9                                       Titanic  Hollywood    200.00
# 10                        It's a Wonderful Life  Hollywood      3.18
# 11                                       Avatar  Hollywood    237.00
# 12                                The Godfather  Hollywood      7.20
# ...

# %%
d[d.release_year >2000]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 11                                       Avatar  Hollywood          2009
# 13                              The Dark Knight  Hollywood          2008
# 16                                     Parasite  Hollywood          2019
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# ...

# %%
d[d.studio == "Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
d.studio.unique()
# Out:
# array(['Government of West Bengal', 'Marvel Studios',
#        'Castle Rock Entertainment', 'Warner Bros. Pictures',
#        'Columbia Pictures', 'Universal Pictures  ', 'Paramount Pictures',
#        'Liberty Films', '20th Century Fox', 'Syncopy',
#        'Universal Pictures', nan, 'Yash Raj Films', 'Vinod Chopra Films',
#        'Dharma Productions', 'Vinod Chopra Productions', 'Zee Studios',
#        'Salman Khan Films', 'Hombale Films', 'Mythri Movie Makers',
#        'DVV Entertainment', 'Arka Media Works'], dtype=object)

# %%
d.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
d.imdb_rating.max()
# Out:
# 9.3

# %%
d[(d.imdb_rating == d.imdb_rating.max()) | (d.imdb_rating == d.imdb_rating.min())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
d["age"] = d["release_year"].apply(lambda x: 2023 - x)
d
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
d["profit"] = d.apply(lambda x: x["revenue"] - x["budget"], axis = 1)
d
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
d.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
d.set_index("title", inplace = True)

# %%
d
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
d.loc ["Pather Panchali"]
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# age                                    68
# profit                            30000.0
# Name: Pather Panchali, dtype: object

# %%
d.iloc[2]
# Out:
# industry             Hollywood
# release_year              2013
# imdb_rating                6.8
# studio          Marvel Studios
# budget                   165.0
# revenue                  644.8
# unit                  Millions
# currency                   USD
# language               English
# age                         10
# profit                   479.8
# Name: Thor: The Dark World , dtype: object

# %%
d.reset_index(inplace = True)

# %%
d
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
d.set_index("title")
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
# The Shawshank Redemption                     Hollywood          1994
# Interstellar                                 Hollywood          2014
# The Pursuit of Happyness                     Hollywood          2006
# Gladiator                                    Hollywood          2000
# Titanic                                      Hollywood          1997
# It's a Wonderful Life                        Hollywood          1946
# Avatar                                       Hollywood          2009
# ...

# %%
f = pd.read_csv("C:\\Users\\m9wrc\\OneDrive\\Desktop\\Python\\stock_data.csv", skiprows = 1)

# %%
f
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
f = pd.read_csv("C:\\Users\\m9wrc\\OneDrive\\Desktop\\Python\\stock_data.csv", 
                skiprows = 1, 
                header = 1,  
                names = ["Tickers", "EPS", "Revenue", "Price", "People"], 
                nrows = 3, 
                na_values = ["not available", "n.a."])

# %%
f
# Out:
#   Tickers   EPS  Revenue  Price         People
# 0     WMT  4.61      484     65            NaN
# 1    MSFT -1.00       85     64     bill gates
# 2    RIL    NaN       50   1023  mukesh ambani

# %%
f.to_csv("stocks.csv", index = False, header = False)

# %%
import os
print(os.getcwd())
# Out:
# C:\MyPythonLearningJourney\MyPythonLearningJourny\Code With Harry

# %%
movies

# %%
movies = pd.read_excel("C:\\Users\\m9wrc\\OneDrive\\Desktop\\Python\\movies_db.xlsx", "movies")

# %%
movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
financials = pd.read_excel("C:\\Users\\m9wrc\\OneDrive\\Desktop\\Python\\movies_db.xlsx", "financials")

# %%
financials.head(3)
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions       $$

# %%
def standardize_currency(curr):
    if curr == "$$" or curr == "Dollars":
        return "USD"
    return curr
    
    
financials = pd.read_excel("C:\\Users\\m9wrc\\OneDrive\\Desktop\\Python\\movies_db.xlsx", "financials", converters =
                          {
                              "currency" : standardize_currency
                          })

# %%
financials
# Out:
#     movie_id    budget   revenue       unit currency
# 0        101      1.00      12.5   Billions      INR
# 1        102    200.00     954.8   Millions      USD
# 2        103    165.00     644.8   Millions      USD
# 3        104    180.00     854.0   Millions      USD
# 4        105    250.00     670.0   Millions      USD
# 5        107    400.00    2000.0   Millions      INR
# 6        108    550.00    4000.0   Millions      INR
# 7        109    390.00    1360.0   Millions      INR
# 8        110      1.40       3.5   Billions      INR
# 9        111     25.00      73.3   Millions      USD
# 10       113    165.00     701.8   Millions      USD
# 11       114    205.00     365.3   Millions      USD
# 12       115     55.00     307.1   Millions      USD
# 13       116    103.00     460.5   Millions      USD
# 14       117    200.00    2202.0   Millions      USD
# 15       118      3.18       3.3   Millions      USD
# 16       119    237.00    2847.0   Millions      USD
# ...

# %%
financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  40 non-null     int64
#  1   budget    40 non-null     float64
#  2   revenue   40 non-null     float64
#  3   unit      40 non-null     object
#  4   currency  40 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.7+ KB

# %%
financials.describe()
# Out:
#          movie_id       budget        revenue
# count   40.000000     40.00000      40.000000
# mean   135.500000   1938.47700    3847.152500
# std     64.555681  11039.53489   15759.558582
# min    101.000000      1.00000       3.100000
# 25%    112.500000     20.37500     284.025000
# 50%    122.500000    165.00000     685.900000
# 75%    132.250000    250.00000    1520.000000
# max    412.000000  70000.00000  100000.000000

# %%
merged = pd.merge(movies, financials, on = "movie_id")

# %%
merged
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 6        108                                     3 Idiots  Bollywood
# 7        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 8        110                             Bajirao Mastani   Bollywood
# 9        111                     The Shawshank Redemption  Hollywood
# 10       113                                 Interstellar  Hollywood
# 11       115                     The Pursuit of Happyness  Hollywood
# 12       116                                    Gladiator  Hollywood
# ...

# %%
merged.to_excel("merged.xlsx", sheet_name = "merged", index = False)

# %%
names = pd.DataFrame(
{
    "Name" : ["Mayank", "Shilpi", "Shrishti"]
})

# %%
age = pd.DataFrame({
    "Age" : [30, 32, 28]
})

# %%
with pd.ExcelWriter("Name_Age.xlsx") as writer:
    names.to_excel(writer, sheet_name = "Names", index = False)
    age.to_excel(writer, sheet_name = "Age", index = False)
